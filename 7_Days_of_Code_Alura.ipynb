# %% [markdown]
# <a href="https://colab.research.google.com/github/DMaciente/7_Days_of_Code_Alura/blob/main/7_Days_of_Code_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importando Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gerando DATAFRAME com emprestimos
# df_emprestimo

# %%
url_base = 'https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/'

# %%
arquivos = ['emprestimos-20101.csv', 'emprestimos-20102.csv', 'emprestimos-20111.csv',
            'emprestimos-20112.csv', 'emprestimos-20121.csv', 'emprestimos-20122.csv',
            'emprestimos-20131.csv', 'emprestimos-20132.csv', 'emprestimos-20141.csv',
            'emprestimos-20142.csv', 'emprestimos-20151.csv', 'emprestimos-20152.csv',
            'emprestimos-20161.csv', 'emprestimos-20162.csv', 'emprestimos-20171.csv',
            'emprestimos-20172.csv', 'emprestimos-20181.csv', 'emprestimos-20182.csv',
            'emprestimos-20191.csv', 'emprestimos-20192.csv', 'emprestimos-20201.csv']

# %%
df_emprestimo = pd.DataFrame()

for arquivo in arquivos:
  url = url_base + arquivo
  df = pd.read_csv(url)
  df_emprestimo = pd.concat([df_emprestimo, df])

df_emprestimo = df_emprestimo.drop_duplicates()

# %%
df_emprestimo.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# ...

# %%
df_emprestimo.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# ### Gerando DATAFRAME com exemplares
# df_exemplar

# %%
 df_exemplar = pd.read_parquet('https://raw.githubusercontent.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
 df_exemplar.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %% [markdown]
# ### Juntando os DATAFRAMES

# %%
df_final = pd.merge(df_emprestimo, df_exemplar, on='codigo_barras')

# %%
df_final
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               726965       L095049  2010/03/31 12:41:08.684000000
# 2               709685       L167050                            NaN
# 3               717763       L167050                            NaN
# 4               729996       L167050  2010/03/17 09:08:26.874000000
# ...                ...           ...                            ...
# 2072517        2989018    2009036492                            NaN
# 2072518        2989020    2014062640                            NaN
# 2072519        2989032    2018003324                            NaN
# 2072520        2989049    2006024313                            NaN
# 2072521        2989061    2018031352                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %% [markdown]
# ### ETL

# %%
# excluíndo coluna 'registro de sistema'
df_final = df_final.drop(columns=['registro_sistema'])

# %%
# transformando coluna 'matricula_ou_siape' em string
df_final['matricula_ou_siape'] = df_final['matricula_ou_siape'].astype(str)

# %%
# incluíndo coluna 'classificacao' do sistema CDU - Classificação Decimal Universal com base na coluna localização
# 000 a 099: Generalidades. Ciência e conhecimento.
# 100 a 199: Filosofia e psicologia.
# 200 a 299: Religião.
# 300 a 399: Ciências sociais.
# 400 a 499: Classe vaga. Provisoriamente não ocupada.
# 500 a 599: Matemática e ciências naturais.
# 600 a 699: Ciências aplicadas.
# 700 a 799: Belas artes.
# 800 a 899: Linguagem. Língua. Linguística.
# 900 a 999: Geografia. Biografia. História.

df_final.loc[(df_final['localizacao'] >= 0) & (df_final['localizacao'] <= 99), 'classificacao'] = 'Generalidades. Ciência e conhecimento.'
df_final.loc[(df_final['localizacao'] >= 100) & (df_final['localizacao'] <= 199), 'classificacao'] = 'Filosofia e psicologia.'
df_final.loc[(df_final['localizacao'] >= 200) & (df_final['localizacao'] <= 299), 'classificacao'] = 'Religião.'
df_final.loc[(df_final['localizacao'] >= 300) & (df_final['localizacao'] <= 399), 'classificacao'] = 'Ciências sociais.'
df_final.loc[(df_final['localizacao'] >= 400) & (df_final['localizacao'] <= 499), 'classificacao'] = 'Classe vaga. Provisoriamente não ocupada.'
df_final.loc[(df_final['localizacao'] >= 500) & (df_final['localizacao'] <= 599), 'classificacao'] = 'Matemática e ciências naturais.'
df_final.loc[(df_final['localizacao'] >= 600) & (df_final['localizacao'] <= 699), 'classificacao'] = 'Ciências aplicadas.'
df_final.loc[(df_final['localizacao'] >= 700) & (df_final['localizacao'] <= 799), 'classificacao'] = 'Belas artes.'
df_final.loc[(df_final['localizacao'] >= 800) & (df_final['localizacao'] <= 899), 'classificacao'] = 'Linguagem. Língua. Linguística.'
df_final.loc[(df_final['localizacao'] >= 900) & (df_final['localizacao'] <= 999), 'classificacao'] = 'Geografia. Biografia. História.'

# %%
# transformando colunadas de datas em type datetime
df_final['data_emprestimo'] = pd.to_datetime(df_final['data_emprestimo'])
df_final['data_devolucao'] = pd.to_datetime(df_final['data_devolucao'])
df_final['data_renovacao'] = pd.to_datetime(df_final['data_renovacao'])

# %%
# inserir colunas com ANO, MES e HORAS
df_final['ano_emprestimo'] = df_final['data_emprestimo'].dt.year
df_final['mes_emprestimo'] = df_final['data_emprestimo'].dt.month
df_final['hora_emprestimo'] = df_final['data_emprestimo'].dt.hour

# %%
df_final.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         726965       L095049 2010-03-31 12:41:08.684
# 2         709685       L167050                     NaT
# 3         717763       L167050                     NaT
# 4         729996       L167050 2010-03-17 09:08:26.874
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-03-01 12:40:56.212 2010-04-30 14:42:35.366       2009121584.0
# 2 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 3 2010-02-11 11:16:30.335 2010-03-04 08:54:32.262       2008050352.0
# 4 2010-03-04 13:36:26.599 2010-03-31 18:04:29.669        200722565.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1  ALUNO DE PÓS-GRADUAÇÃO        13259  Acervo Circulante
# ...

# %%
emprestimo_ano = df_final.groupby('ano_emprestimo')['id_emprestimo'].count().reset_index()
emprestimo_ano
# Out:
#     ano_emprestimo  id_emprestimo
# 0             2010         161394
# 1             2011         196390
# 2             2012         221365
# 3             2013         234749
# 4             2014         219189
# 5             2015         213582
# 6             2016         215900
# 7             2017         218462
# 8             2018         194080
# 9             2019         171801
# 10            2020          25610

# %%
emprestimo_mes = df_final.groupby('mes_emprestimo')['id_emprestimo'].count().reset_index()
emprestimo_mes.sort_values(by='id_emprestimo', ascending=False)
# Out:
#     mes_emprestimo  id_emprestimo
# 2                3         252185
# 7                8         232793
# 1                2         210200
# 3                4         208725
# 8                9         208234
# 4                5         202530
# 9               10         188410
# 10              11         164222
# 5                6         138123
# 6                7         123790
# 11              12          75796
# 0                1          67514

# %%
emprestimo_hora = df_final.groupby('hora_emprestimo')['id_emprestimo'].count().reset_index()
emprestimo_hora #.sort_values(by='id_emprestimo', ascending=False)
# Out:
#     hora_emprestimo  id_emprestimo
# 0                 0             17
# 1                 6             14
# 2                 7          18777
# 3                 8         103416
# 4                 9         131273
# 5                10         185839
# 6                11         180048
# 7                12         148754
# 8                13         126987
# 9                14         150876
# 10               15         166672
# 11               16         210655
# 12               17         185340
# 13               18         182520
# 14               19         102129
# 15               20         127716
# 16               21          51191
# 17               22            247
# 18               23             51

# %%
# grafico de linha emprestimo_ano
plt.figure(figsize=(12, 6))
plt.plot(emprestimo_ano['ano_emprestimo'], emprestimo_ano['id_emprestimo'])
plt.xlabel('Ano')
plt.ylabel('Quantidade')
plt.title('Quantidade de Livros Emprestados por Ano')
plt.show()

# %%
# grafico de linha emprestimo por mês
plt.figure(figsize=(12, 6))
plt.plot(emprestimo_mes['mes_emprestimo'], emprestimo_mes['id_emprestimo'])
plt.xlabel('Mes')
plt.ylabel('Quantidade')
plt.title('Quantidade de Livros Emprestados por Meses')
plt.show()

# %%
# grafico de barras emprestimo por horas
plt.figure(figsize=(12, 6))
plt.bar(emprestimo_hora['hora_emprestimo'], emprestimo_hora['id_emprestimo'])
plt.xlabel('Hora')
plt.ylabel('Quantidade')
plt.title('Quantidade de Livros Emprestados por Horas')
plt.show()

# %%
#Variáveis categóricas das quais precisaremos extrair mais informações. Elas são:
# Tipo de vínculo
# Coleção
# Biblioteca
# Classificação geral da CDU

# Gere uma tabela de frequência e com o percentual para cada variável.

def gerar_frequencia(variavel):
  frequencia = df_final[variavel].value_counts().reset_index()
  frequencia.columns = [variavel, 'frequencia']
  frequencia['percentual'] = round((frequencia['frequencia'] / frequencia['frequencia'].sum()) * 100, 2)
  print(f'Tabela de Frequencia - {variavel}')
  return frequencia

# %%
gerar_frequencia('tipo_vinculo_usuario')
# Out:
# Tabela de Frequencia - tipo_vinculo_usuario
#               tipo_vinculo_usuario  frequencia  percentual
# 0               ALUNO DE GRADUAÇÃO     1612324       77.80
# 1           ALUNO DE PÓS-GRADUAÇÃO      302541       14.60
# 2                          DOCENTE       70981        3.42
# 3  SERVIDOR TÉCNICO-ADMINISTRATIVO       32184        1.55
# 4              ALUNO MÉDIO/TÉCNICO       28029        1.35
# 5                  DOCENTE EXTERNO       23949        1.16
# 6                  USUÁRIO EXTERNO        2509        0.12
# 7                           OUTROS           5        0.00

# %%
gerar_frequencia('colecao')
# Out:
# Tabela de Frequencia - colecao
#                                   colecao  frequencia  percentual
# 0                       Acervo Circulante     2053120       99.06
# 1                              Multimeios        7954        0.38
# 2                             Monografias        4021        0.19
# 3                            Dissertações        2406        0.12
# 4                     Obras de Referência        1954        0.09
# 5            Publicações de Autores do RN         866        0.04
# 6                     Publicações da UFRN         764        0.04
# 7                                   Teses         714        0.03
# 8                                Folhetos         271        0.01
# 9   Necessidades Educacionais Específicas         130        0.01
# 10                     Trabalho Acadêmico         115        0.01
# 11                                Eventos         101        0.00
# 12                    Coleção Mossoroense          44        0.00
# ...

# %%
gerar_frequencia('biblioteca')
# Out:
# Tabela de Frequencia - biblioteca
#                                            biblioteca  frequencia  percentual
# 0                      Biblioteca Central Zila Mamede     1426122       68.81
# 1   Biblioteca Setorial do Centro Ciências da Saúd...      118614        5.72
# 2   Biblioteca Setorial da Faculdade de Ciências d...       77609        3.74
# 3   Biblioteca Setorial Prof. Alberto Moreira Camp...       66447        3.21
# 4   Biblioteca Setorial Profª. Maria Lúcia da Cost...       61478        2.97
# 5   Biblioteca Setorial Bertha Cruz Enders - ­Esco...       46040        2.22
# 6   Biblioteca Setorial do Centro de Ciências Huma...       40744        1.97
# 7   Biblioteca Setorial Dr. Paulo Bezerra - EMCM/R...       32097        1.55
# 8   Biblioteca Setorial Profª. Maria José Mamede G...       29089        1.40
# 9   Biblioteca Setorial Prof. Rodolfo Helinski - E...       27219        1.31
# 10  Biblioteca Setorial Prof. Francisco Gurgel De ...       26923        1.30
# ...

# %%
gerar_frequencia('classificacao')
# Out:
# Tabela de Frequencia - classificacao
#                             classificacao  frequencia  percentual
# 0                     Ciências aplicadas.     1425473       68.78
# 1                       Ciências sociais.      369536       17.83
# 2         Matemática e ciências naturais.       68744        3.32
# 3  Generalidades. Ciência e conhecimento.       62521        3.02
# 4                               Religião.       62295        3.01
# 5                 Filosofia e psicologia.       60563        2.92
# 6         Geografia. Biografia. História.        7989        0.39
# 7                            Belas artes.        7911        0.38
# 8         Linguagem. Língua. Linguística.        7490        0.36
